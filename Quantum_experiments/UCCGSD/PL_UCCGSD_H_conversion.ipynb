# %%
import re
import pennylane as qml
from pennylane import FermiC, FermiA
from pennylane import numpy as np
import itertools

# Manual orbital reordering to go from block labeling of indicies to Pennylane ordering
reordering_map = {
    0: 0, 1: 1, 2: 2, 3: 6, 4: 7, 5: 8,
    6: 3, 7: 4, 8: 5, 9: 9, 10: 10, 11: 11
}

# Parse fermionic Hamiltonian terms into (coefficient, operator list)
def parse_term(term_str):
    match = re.match(r"\(([^)]+)\)(.*)", term_str.strip())
    if not match:
        raise ValueError(f"Invalid format: {term_str}")
    
    coeff_str, ops_str = match.groups()
    coeff = float(coeff_str.split(',')[0])
    
    ops = []
    if ops_str.strip():  
        for op in ops_str.strip().split():
            if op.endswith("^"):
                idx = int(op[:-1])
                dagger = True
            else:
                idx = int(op)
                dagger = False
            remapped_idx = reordering_map[idx]
            ops.append((remapped_idx, dagger))
    
    return coeff, ops

# Load Hamiltonian from external text file
def load_hamiltonian(filename):
    with open(filename, 'r') as f:
        content = f.read()
    terms = [t.strip() for t in content.split('+') if t.strip()]
    return [parse_term(t) for t in terms]

# Convert into Pennylane fermionic operators
def build_fermionic_operator(parsed_terms):
    total_op = 0
    for coeff, ops in parsed_terms:
        op = None
        for idx, dagger in ops:
            term = FermiC(idx) if dagger else FermiA(idx)
            op = term if op is None else op * term
        if op is not None:
            total_op += float(coeff) * op
        else:
            total_op += float(coeff)  # constant/identity term
    return total_op

parsed_terms = load_hamiltonian("Benzene_VDZ_ferm.txt")

fermionic_op = build_fermionic_operator(parsed_terms)
#print(fermionic_op)

# Jordan-Wigner to convert to qubit Hamiltonian
jw_op = qml.fermi.jordan_wigner(fermionic_op)

# Reconstruct the Hamiltonian with only real parts of the coefficients
H = sum(c.real * t for c, t in zip(jw_op.coeffs, jw_op.ops))

qubits = 12
electrons = 6
wires = list(range(qubits))

# Construct Hartree-Fock state
hf_state = qml.qchem.hf_state(electrons, qubits)

# Generate generalized singles and doubles excitations
combinations = list(itertools.combinations(range(12), 2))
singles = [list(combo) for combo in combinations]
combinations = list(itertools.combinations(range(12), 4))
doubles = [list(combo) for combo in combinations]

dev = qml.device("lightning.qubit", wires=qubits)

# Construct circuit with 2 repetition UCCGSD ansatz 
def circuit_1(params, *, excitations):
    qml.BasisState(hf_state, wires=range(qubits))

    for i, excitation in enumerate(excitations):
        if len(excitation) == 4:
            qml.DoubleExcitation(params[i], wires=excitation)
        else:
            qml.SingleExcitation(params[i], wires=excitation)

    for i, excitation in enumerate(excitations):
        if len(excitation) == 4:
            qml.DoubleExcitation(params[i+len(doubles)], wires=excitation)
        else:
            qml.SingleExcitation(params[i+len(singles)], wires=excitation)
    return qml.expval(H)

cost_fn = qml.QNode(circuit_1, dev)

# Initialize parameters
params = np.zeros(2*(len(doubles)+len(singles)))

# Choose optimizer
optimizer = qml.AdagradOptimizer(stepsize=1.5, eps=1e-08)

# Carry out optimization

max_steps = 20000  

for m in range(max_steps):
    params, energy = optimizer.step_and_cost(cost_fn, params, excitations=singles+doubles)
    
    if m % 2 == 0:
        print(f"Step = {m},  E = {float(energy):.8f} Ha")
# Out:
# Step = 2730,  E = -231.57100042 Ha
# Step = 2732,  E = -231.57099861 Ha
# Step = 2734,  E = -231.57099685 Ha
# Step = 2736,  E = -231.57099514 Ha
# Step = 2738,  E = -231.57099349 Ha
# Step = 2740,  E = -231.57099193 Ha
# Step = 2742,  E = -231.57099044 Ha
# Step = 2744,  E = -231.57098906 Ha
# Step = 2746,  E = -231.57098778 Ha
# Step = 2748,  E = -231.57098662 Ha
# Step = 2750,  E = -231.57098559 Ha
# Step = 2752,  E = -231.57098469 Ha
# Step = 2754,  E = -231.57098394 Ha
# Step = 2756,  E = -231.57098333 Ha
# Step = 2758,  E = -231.57098288 Ha
# Step = 2760,  E = -231.57098258 Ha
# Step = 2762,  E = -231.57098245 Ha
# Step = 2764,  E = -231.57098248 Ha
# Step = 2766,  E = -231.57098267 Ha
# Step = 2768,  E = -231.57098302 Ha
# Step = 2770,  E = -231.57098354 Ha
# Step = 2772,  E = -231.57098421 Ha
# ...
#      67     if forward is None:
#
# File c:\Users\myer522\OneDrive - PNNL\Desktop\PennyLane_Codes\venv\Lib\site-packages\pennylane\optimize\gradient_descent.py:122, in GradientDescentOptimizer.compute_grad(objective_fn, args, kwargs, grad_fn)
#     104 r"""Compute the gradient of the objective function at the given point and return it along with
#     105 the objective function forward pass (if available).
#     106
#    (...)    119     will not be evaluated and instead ``None`` will be returned.
#     120 """
#     121 g = get_gradient(objective_fn) if grad_fn is None else grad_fn
# --> 122 grad = g(*args, **kwargs)
#     123 forward = getattr(g, "forward", None)
#     125 num_trainable_args = sum(getattr(arg, "requires_grad", False) for arg in args)
#
# File c:\Users\myer522\OneDrive - PNNL\Desktop\PennyLane_Codes\venv\Lib\site-packages\pennylane\_grad.py:224, in grad.__call__(self, *args, **kwargs)
#     221     self._forward = self._fun(*args, **kwargs)
#     222     return ()
# --> 224 grad_value, ans = grad_fn(*args, **kwargs)  # pylint: disable=not-callable
#     225 self._forward = ans
#     227 return grad_value
#
# File c:\Users\myer522\OneDrive - PNNL\Desktop\PennyLane_Codes\venv\Lib\site-packages\autograd\wrap_util.py:20, in unary_to_nary.<locals>.nary_operator.<locals>.nary_f(*args, **kwargs)
#      18 else:
#      19     x = tuple(args[i] for i in argnum)
# ---> 20 return unary_operator(unary_f, x, *nary_op_args, **nary_op_kwargs)
#
# File c:\Users\myer522\OneDrive - PNNL\Desktop\PennyLane_Codes\venv\Lib\site-packages\pennylane\_grad.py:242, in grad._grad_with_forward(fun, x)
#     236 @staticmethod
#     237 @unary_to_nary
#     238 def _grad_with_forward(fun, x):
#     239     """This function is a replica of ``autograd.grad``, with the only
#     240     difference being that it returns both the gradient *and* the forward pass
#     241     value."""
# --> 242     vjp, ans = _make_vjp(fun, x)  # pylint: disable=redefined-outer-name
#     244     if vspace(ans).size != 1:
#     245         raise TypeError(
#     246             "Grad only applies to real scalar-output functions. "
#     247             "Try jacobian, elementwise_grad or holomorphic_grad."
#     248         )
#
# File c:\Users\myer522\OneDrive - PNNL\Desktop\PennyLane_Codes\venv\Lib\site-packages\autograd\core.py:10, in make_vjp(fun, x)
#       8 def make_vjp(fun, x):
#       9     start_node = VJPNode.new_root()
# ---> 10     end_value, end_node =  trace(start_node, fun, x)
#      11     if end_node is None:
#      12         def vjp(g): return vspace(x).zeros()
#
# File c:\Users\myer522\OneDrive - PNNL\Desktop\PennyLane_Codes\venv\Lib\site-packages\autograd\tracer.py:10, in trace(start_node, fun, x)
#       8 with trace_stack.new_trace() as t:
#       9     start_box = new_box(x, t, start_node)
# ---> 10     end_box = fun(start_box)
#      11     if isbox(end_box) and end_box._trace == start_box._trace:
#      12         return end_box._value, end_box._node
#
# File c:\Users\myer522\OneDrive - PNNL\Desktop\PennyLane_Codes\venv\Lib\site-packages\autograd\wrap_util.py:15, in unary_to_nary.<locals>.nary_operator.<locals>.nary_f.<locals>.unary_f(x)
#      13 else:
#      14     subargs = subvals(args, zip(argnum, x))
# ---> 15 return fun(*subargs, **kwargs)
#
# File c:\Users\myer522\OneDrive - PNNL\Desktop\PennyLane_Codes\venv\Lib\site-packages\pennylane\workflow\qnode.py:882, in QNode.__call__(self, *args, **kwargs)
#     879     from ._capture_qnode import capture_qnode  # pylint: disable=import-outside-toplevel
#     881     return capture_qnode(self, *args, **kwargs)
# --> 882 return self._impl_call(*args, **kwargs)
#
# File c:\Users\myer522\OneDrive - PNNL\Desktop\PennyLane_Codes\venv\Lib\site-packages\pennylane\workflow\qnode.py:855, in QNode._impl_call(self, *args, **kwargs)
#     852 # Calculate the classical jacobians if necessary
#     853 self._transform_program.set_classical_component(self, args, kwargs)
# --> 855 res = qml.execute(
#     856     (tape,),
#     857     device=self.device,
#     858     diff_method=self.diff_method,
#     859     interface=self.interface,
#     860     transform_program=self._transform_program,
#     861     gradient_kwargs=self.gradient_kwargs,
#     862     **self.execute_kwargs,
#     863 )
#     864 res = res[0]
#     866 # convert result to the interface in case the qfunc has no parameters
#
# File c:\Users\myer522\OneDrive - PNNL\Desktop\PennyLane_Codes\venv\Lib\site-packages\pennylane\workflow\execution.py:244, in execute(tapes, device, diff_method, interface, transform_program, grad_on_execution, cache, cachesize, max_diff, device_vjp, postselect_mode, mcm_method, gradient_kwargs, mcm_config, config, inner_transform)
#     241 if transform_program.is_informative:
#     242     return post_processing(tapes)
# --> 244 results = run(tapes, device, config, inner_transform)
#     245 return post_processing(results)
#
# File c:\Users\myer522\OneDrive - PNNL\Desktop\PennyLane_Codes\venv\Lib\site-packages\pennylane\workflow\run.py:332, in run(tapes, device, config, inner_transform_program)
#     329         params = tape.get_parameters(trainable_only=False)
#     330         tape.trainable_params = qml.math.get_trainable_indices(params)
# --> 332 results = ml_execute(tapes, execute_fn, jpc, device=device)
#     333 return results
#
# File c:\Users\myer522\OneDrive - PNNL\Desktop\PennyLane_Codes\venv\Lib\site-packages\pennylane\workflow\interfaces\autograd.py:147, in autograd_execute(tapes, execute_fn, jpc, device)
#     142 # pylint misidentifies autograd.builtins as a dict
#     143 # pylint: disable=no-member
#     144 parameters = autograd.builtins.tuple(
#     145     [autograd.builtins.list(t.get_parameters()) for t in tapes]
#     146 )
# --> 147 return _execute(parameters, tuple(tapes), execute_fn, jpc)
#
# File c:\Users\myer522\OneDrive - PNNL\Desktop\PennyLane_Codes\venv\Lib\site-packages\autograd\tracer.py:44, in primitive.<locals>.f_wrapped(*args, **kwargs)
#      42 parents = tuple(box._node for _     , box in boxed_args)
#      43 argnums = tuple(argnum    for argnum, _   in boxed_args)
# ---> 44 ans = f_wrapped(*argvals, **kwargs)
#      45 node = node_constructor(ans, f_wrapped, argvals, kwargs, argnums, parents)
#      46 return new_box(ans, trace, node)
#
# File c:\Users\myer522\OneDrive - PNNL\Desktop\PennyLane_Codes\venv\Lib\site-packages\autograd\tracer.py:48, in primitive.<locals>.f_wrapped(*args, **kwargs)
#      46     return new_box(ans, trace, node)
#      47 else:
# ---> 48     return f_raw(*args, **kwargs)
#
# File c:\Users\myer522\OneDrive - PNNL\Desktop\PennyLane_Codes\venv\Lib\site-packages\pennylane\workflow\interfaces\autograd.py:183, in _execute(parameters, tapes, execute_fn, jpc)
#     165 @autograd.extend.primitive
#     166 def _execute(
#     167     parameters,
#    (...)    170     jpc,
#     171 ):  # pylint: disable=unused-argument
#     172     """Autodifferentiable wrapper around a way of executing tapes.
#     173
#     174     Args:
#    (...)    181
#     182     """
# --> 183     return _to_autograd(execute_fn(tapes))
#
# File c:\Users\myer522\OneDrive - PNNL\Desktop\PennyLane_Codes\venv\Lib\site-packages\pennylane\workflow\jacobian_products.py:482, in DeviceDerivatives.execute_and_cache_jacobian(self, tapes)
#     480 if logger.isEnabledFor(logging.DEBUG):  # pragma: no cover
#     481     logger.debug("Forward pass called with %s", tapes)
# --> 482 results, jac = self._dev_execute_and_compute_derivatives(tapes)
#     483 self._results_cache[tapes] = results
#     484 self._jacs_cache[tapes] = jac
#
# File c:\Users\myer522\OneDrive - PNNL\Desktop\PennyLane_Codes\venv\Lib\site-packages\pennylane\workflow\jacobian_products.py:447, in DeviceDerivatives._dev_execute_and_compute_derivatives(self, tapes)
#     441 """
#     442 Converts tapes to numpy before computing the the results and derivatives on the device.
#     443
#     444 Dispatches between the two different device interfaces.
#     445 """
#     446 numpy_tapes, _ = qml.transforms.convert_to_numpy_parameters(tapes)
# --> 447 return self._device.execute_and_compute_derivatives(numpy_tapes, self._execution_config)
#
# File c:\Users\myer522\OneDrive - PNNL\Desktop\PennyLane_Codes\venv\Lib\site-packages\pennylane\devices\modifiers\simulator_tracking.py:95, in _track_execute_and_compute_derivatives.<locals>.execute_and_compute_derivatives(self, circuits, execution_config)
#      89     self.tracker.update(
#      90         execute_and_derivative_batches=1,
#      91         executions=len(batch),
#      92         derivatives=len(batch),
#      93     )
#      94     self.tracker.record()
# ---> 95 return untracked_execute_and_compute_derivatives(self, circuits, execution_config)
#
# File c:\Users\myer522\OneDrive - PNNL\Desktop\PennyLane_Codes\venv\Lib\site-packages\pennylane\devices\modifiers\single_tape_support.py:60, in _make_execute_and_compute_derivatives.<locals>.execute_and_compute_derivatives(self, circuits, execution_config)
#      58     is_single_circuit = True
#      59     circuits = (circuits,)
# ---> 60 results, jacs = batch_execute_and_compute_derivatives(self, circuits, execution_config)
#      61 return (results[0], jacs[0]) if is_single_circuit else (results, jacs)
#
# File c:\Users\myer522\OneDrive - PNNL\Desktop\PennyLane_Codes\venv\Lib\site-packages\pennylane\devices\modifiers\simulator_tracking.py:95, in _track_execute_and_compute_derivatives.<locals>.execute_and_compute_derivatives(self, circuits, execution_config)
#      89     self.tracker.update(
#      90         execute_and_derivative_batches=1,
#      91         executions=len(batch),
#      92         derivatives=len(batch),
#      93     )
#      94     self.tracker.record()
# ---> 95 return untracked_execute_and_compute_derivatives(self, circuits, execution_config)
#
# File c:\Users\myer522\OneDrive - PNNL\Desktop\PennyLane_Codes\venv\Lib\site-packages\pennylane\devices\modifiers\single_tape_support.py:60, in _make_execute_and_compute_derivatives.<locals>.execute_and_compute_derivatives(self, circuits, execution_config)
#      58     is_single_circuit = True
#      59     circuits = (circuits,)
# ---> 60 results, jacs = batch_execute_and_compute_derivatives(self, circuits, execution_config)
#      61 return (results[0], jacs[0]) if is_single_circuit else (results, jacs)
#
# File c:\Users\myer522\OneDrive - PNNL\Desktop\PennyLane_Codes\venv\Lib\site-packages\pennylane_lightning\core\lightning_base.py:377, in LightningBase.execute_and_compute_derivatives(self, circuits, execution_config)
#     367 """Compute the results and jacobians of circuits at the same time.
#     368
#     369 Args:
#    (...)    374     Tuple: A numeric result of the computation and the gradient.
#     375 """
#     376 batch_obs = execution_config.device_options.get("batch_obs", self._batch_obs)
# --> 377 results = tuple(
#     378     self.simulate_and_jacobian(
#     379         self.dynamic_wires_from_circuit(circuit),
#     380         self._statevector,
#     381         batch_obs=batch_obs,
#     382         wire_map=self._wire_map,
#     383     )
#     384     for circuit in circuits
#     385 )
#     386 return tuple(zip(*results))
#
# File c:\Users\myer522\OneDrive - PNNL\Desktop\PennyLane_Codes\venv\Lib\site-packages\pennylane_lightning\core\lightning_base.py:378, in <genexpr>(.0)
#     367 """Compute the results and jacobians of circuits at the same time.
#     368
#     369 Args:
#    (...)    374     Tuple: A numeric result of the computation and the gradient.
#     375 """
#     376 batch_obs = execution_config.device_options.get("batch_obs", self._batch_obs)
#     377 results = tuple(
# --> 378     self.simulate_and_jacobian(
#     379         self.dynamic_wires_from_circuit(circuit),
#     380         self._statevector,
#     381         batch_obs=batch_obs,
#     382         wire_map=self._wire_map,
#     383     )
#     384     for circuit in circuits
#     385 )
#     386 return tuple(zip(*results))
#
# File c:\Users\myer522\OneDrive - PNNL\Desktop\PennyLane_Codes\venv\Lib\site-packages\pennylane_lightning\core\lightning_base.py:266, in LightningBase.simulate_and_jacobian(self, circuit, state, batch_obs, wire_map)
#     264 if wire_map is not None:
#     265     [circuit], _ = qml.map_wires(circuit, wire_map)
# --> 266 res = self.simulate(circuit, state)
#     267 # pylint: disable=not-callable
#     268 jac = self.LightningAdjointJacobian(state, batch_obs=batch_obs).calculate_jacobian(circuit)
#
# File c:\Users\myer522\OneDrive - PNNL\Desktop\PennyLane_Codes\venv\Lib\site-packages\pennylane_lightning\lightning_qubit\lightning_qubit.py:520, in LightningQubit.simulate(self, circuit, state, mcmc, postselect_mode)
#     517     return tuple(results)
#     519 final_state = state.get_final_state(circuit)
# --> 520 return self.LightningMeasurements(final_state, **mcmc).measure_final_state(circuit)
#
# File c:\Users\myer522\OneDrive - PNNL\Desktop\PennyLane_Codes\venv\Lib\site-packages\pennylane_lightning\core\_measurements_base.py:281, in LightningBaseMeasurements.measure_final_state(self, circuit, mid_measurements)
#     278 if not circuit.shots:
#     279     # analytic case
#     280     if len(circuit.measurements) == 1:
# --> 281         return self.measurement(circuit.measurements[0])
#     283     return tuple(self.measurement(mp) for mp in circuit.measurements)
#     285 # finite-shot case
#
# File c:\Users\myer522\OneDrive - PNNL\Desktop\PennyLane_Codes\venv\Lib\site-packages\pennylane_lightning\core\_measurements_base.py:262, in LightningBaseMeasurements.measurement(self, measurementprocess)
#     253 def measurement(self, measurementprocess: MeasurementProcess) -> TensorLike:
#     254     """Apply a measurement process to a state.
#     255
#     256     Args:
#    (...)    260         TensorLike: the result of the measurement
#     261     """
# --> 262     return self.get_measurement_function(measurementprocess)(measurementprocess)
#
# File c:\Users\myer522\OneDrive - PNNL\Desktop\PennyLane_Codes\venv\Lib\site-packages\pennylane_lightning\core\_measurements_base.py:142, in LightningBaseMeasurements.expval(self, measurementprocess)
#     134     return self._measurement_lightning.expval(matrix, observable_wires)
#     136 if (measurementprocess.obs.arithmetic_depth > 0) or isinstance(
#     137     measurementprocess.obs.name, List
#     138 ):
#     139     # pylint: disable=protected-access
#     140     ob_serialized = QuantumScriptSerializer(
#     141         self._qubit_state.device_name, self.dtype == np.complex64, self._use_mpi
# --> 142     )._ob(measurementprocess.obs)
#     143     return self._measurement_lightning.expval(ob_serialized)
#     145 return self._measurement_lightning.expval(
#     146     measurementprocess.obs.name, measurementprocess.obs.wires
#     147 )
#
# File c:\Users\myer522\OneDrive - PNNL\Desktop\PennyLane_Codes\venv\Lib\site-packages\pennylane_lightning\core\_serialize.py:371, in QuantumScriptSerializer._ob(self, observable, wires_map)
#     369     return self._named_obs(observable, wires_map)
#     370 if observable.pauli_rep is not None:
# --> 371     return self._pauli_sentence(observable.pauli_rep, wires_map)
#     372 if isinstance(observable, Prod):
#     373     if isinstance(observable, Prod) and observable.has_overlapping_wires:
#
# File c:\Users\myer522\OneDrive - PNNL\Desktop\PennyLane_Codes\venv\Lib\site-packages\pennylane_lightning\core\_serialize.py:352, in QuantumScriptSerializer._pauli_sentence(self, observable, wires_map)
#     350     return self.hamiltonian_obs(np.array([0.0]).astype(self.rtype), [self._ob(Identity(0))])
#     351 pwords, coeffs = zip(*observable.items())
# --> 352 terms = [self._pauli_word(pw, wires_map) for pw in pwords]
#     353 coeffs = np.array(coeffs).astype(self.rtype)
#     355 if self.split_obs:
#
# File c:\Users\myer522\OneDrive - PNNL\Desktop\PennyLane_Codes\venv\Lib\site-packages\pennylane_lightning\core\_serialize.py:341, in QuantumScriptSerializer._pauli_word(self, observable, wires_map)
#     336     wire, pauli = list(observable.items())[0]
#     337     return self.named_obs(PAULI_NAME_MAP[pauli], [map_wire(wire)])
#     339 return self.tensor_obs(
#     340     [
# --> 341         self.named_obs(PAULI_NAME_MAP[pauli], [map_wire(wire)])
#     342         for wire, pauli in observable.items()
#     343     ]
#     344 )
#
# KeyboardInterrupt:
